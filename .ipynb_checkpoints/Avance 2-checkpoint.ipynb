# %% [markdown]
# ## Entrega avance 2 proyecto final vision de máquina
# ### Juan Daniel  Sarmiento Abello 1000331954

# %%
#%matplotlib inline
#import cv2
#from IPython.display import Image
#import numpy as np
#from matplotlib import pyplot as plt

#import matplotlib.image as mpimg

#from scipy.signal import convolve2d as conv2

#from sklearn.preprocessing import StandardScaler
#from sklearn.decomposition import PCA

#from skimage import data, io, filters
#from skimage import color, restoration
#from skimage.util import random_noise, img_as_float

#from skimage import exposure
#from scipy import misc
#from PIL import Image
import os
import cv2
import tensorflow as tf
from tensorflow.keras.callbacks import TensorBoard
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import numpy as np
from matplotlib import pyplot as plt
import matplotlib.pyplot as plt

# %% [markdown]
# ### Cargue de imagenes

# %%
Imagenx= cv2.imread('subset_0_of_S1A_IW_GRDH_1SDV_20200722T104300_20200722T104329_033566_03E3CD_3098_Orb_Cal_TC_Sigma0_VH.png',0)#'C:/Users/Asus/Documents/VisionDeMaquina/ProyectoFinal/PreProcesado/Método 1/Sin Agua/subset_0_of_S1A_IW_GRDH_1SDV_20200722T104300_20200722T104329_033566_03E3CD_3098_Orb_Cal_TC_Sigma0_VH.png'
tamNo = (311,225)
Imagen2=cv2.resize(Imagenx,tamNo)

print(Imagenx.shape)
print(Imagen2.shape)
cv2.imshow('imGGris1',Imagenx)
cv2.imshow('imGGris2',Imagen2)

plt.show()
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# (684, 859)
# (225, 311)

# %%
Imagen1 = cv2.imread('C:/Users/Asus/Documents/VisionDeMaquina/ProyectoFinal/PreProcesado/Método 1/Con Agua/Test/Img1.png',0)
cv2.imshow('imGGris1',Imagen1)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[12], line 2
#       1 Imagen1 = cv2.imread('C:/Users/Asus/Documents/VisionDeMaquina/ProyectoFinal/PreProcesado/Método 1/Con Agua/Test/Img1.png',0)
# ----> 2 cv2.imshow('imGGris1',Imagen1)
#       3 cv2.waitKey(0)
#       4 cv2.destroyAllWindows()
#
# error: OpenCV(4.6.0) C:\ci_311_rebuilds\opencv-suite_1679001454889\work\modules\highgui\src\window.cpp:967: error: (-215:Assertion failed) size.width>0 && size.height>0 in function 'cv::imshow'

# %%
Imagen1 = cv2.imread('Img1.png',0)
Imagen2 = cv2.imread('Img2.png',0)
Imagen3 = cv2.imread('Img3.png',0)
Imagen4 = cv2.imread('Img4.png',0)
Imagen5 = cv2.imread('Img5.png',0)
Imagen6 = cv2.imread('Img6.png',0)
Imagen7 = cv2.imread('Img7.png',0)
Imagen8 = cv2.imread('Img8.png',0)
Imagen9 = cv2.imread('Img9.png',0)
Imagen10 = cv2.imread('Img10.png',0)
Imagen11 = cv2.imread('Img11.png',0)
Imagen12 = cv2.imread('Img12.png',0)
Imagen13 = cv2.imread('Img13.png',0)
Imagen14 = cv2.imread('Img14.png',0)
Imagen15 = cv2.imread('Img15.png',0)
Imagen16 = cv2.imread('Img16.png',0)
Imagen17 = cv2.imread('Img17.png',0)
Imagen18 = cv2.imread('Img18.png',0)
Imagen19 = cv2.imread('Img19.png',0)
Imagen20 = cv2.imread('Img20.png',0)
Imagen21 = cv2.imread('Img21.png',0)
Imagen22 = cv2.imread('Img22.png',0)
Imagen23 = cv2.imread('Img23.png',0)
Imagen24 = cv2.imread('Img24.png',0)
Imagen25 = cv2.imread('Img25.png',0)
Imagen26 = cv2.imread('Img26.png',0)
Imagen27 = cv2.imread('Img27.png',0)
Imagen28 = cv2.imread('Img28.png',0)
Imagen29 = cv2.imread('Img28.png',0)
Imagen30 = cv2.imread('Img30.png',0)
Imagen31 = cv2.imread('Img31.png',0)
Imagen32 = cv2.imread('Img32.png',0)
Imagen33 = cv2.imread('Img33.png',0)
Imagen34 = cv2.imread('Img34.png',0)
Imagen35 = cv2.imread('Img35.png',0)
Imagen36 = cv2.imread('Img36.png',0)
Imagen37 = cv2.imread('Img27.png',0)
Imagen38 = cv2.imread('Img38.png',0)
Imagen39 = cv2.imread('Img39.png',0)
Imagen40 = cv2.imread('Img40.png',0)
Imagen41 = cv2.imread('Img41.png',0)
Imagen42 = cv2.imread('Img42.png',0)
Imagen43 = cv2.imread('Img43.png',0)
Imagen44 = cv2.imread('Img44.png',0)
Imagen45 = cv2.imread('Img45.png',0)
Imagen46 = cv2.imread('Img36.png',0)
Imagen47 = cv2.imread('Img47.png',0)
Imagen48 = cv2.imread('Img48.png',0)
Imagen49 = cv2.imread('Img49.png',0)
Imagen50 = cv2.imread('Img50.png',0)
Imagen51 = cv2.imread('Img51.png',0)
Imagen52 = cv2.imread('Img52.png',0)
Imagen53 = cv2.imread('Img53.png',0)
Imagen54 = cv2.imread('Img54.png',0)
Imagen55 = cv2.imread('Img55.png',0)
Imagen56 = cv2.imread('Img56.png',0)
Imagen57 = cv2.imread('Img57.png',0)
Imagen58 = cv2.imread('Img58.png',0)
Imagen59 = cv2.imread('Img59.png',0)
Imagen60 = cv2.imread('Img60.png',0)
Imagen61 = cv2.imread('Img61.png',0)
Imagen62 = cv2.imread('Img62.png',0)
Imagen63 = cv2.imread('Img63.png',0)
Imagen64 = cv2.imread('Img64.png',0)
Imagen65 = cv2.imread('Img65.png',0)
Imagen66 = cv2.imread('Img66.png',0)
Imagen67 = cv2.imread('Img67.png',0)
Imagen68 = cv2.imread('Img68.png',0)
Imagen69 = cv2.imread('Img69.png',0)
Imagen70 = cv2.imread('Img70.png',0)
Imagen71 = cv2.imread('Img71.png',0)
Imagen72 = cv2.imread('Img72.png',0)
Imagen73 = cv2.imread('Img73.png',0)
Imagen74 = cv2.imread('Img74.png',0)
Imagen75 = cv2.imread('Img75.png',0)
Imagen76 = cv2.imread('Img76.png',0)
Imagen77 = cv2.imread('Img77.png',0)
Imagen78 = cv2.imread('Img78.png',0)
Imagen79 = cv2.imread('Img79.png',0)
Imagen80 = cv2.imread('Img80.png',0)
Imagen81 = cv2.imread('Img81.png',0)
Imagen82 = cv2.imread('Img82.png',0)
Imagen83 = cv2.imread('Img83.png',0)
Imagen84 = cv2.imread('Img84.png',0)
Imagen85 = cv2.imread('Img85.png',0)
Imagen86 = cv2.imread('Img86.png',0)
Imagen87 = cv2.imread('Img87.png',0)

# %%
Test=[Imagen1,Imagen2,Imagen3,Imagen4,Imagen5,Imagen6,Imagen7,Imagen8,Imagen9,Imagen10,Imagen11,Imagen12,Imagen13,Imagen14,Imagen15,Imagen16,Imagen17,Imagen18,Imagen19,Imagen20,Imagen21,Imagen22,Imagen23,Imagen24,Imagen25,Imagen26]
Train=[Imagen27,Imagen28,Imagen29,Imagen30,Imagen31,Imagen32,Imagen33,Imagen34,Imagen35,Imagen36,Imagen37,Imagen38,Imagen39,Imagen40,Imagen41,Imagen42,Imagen43,Imagen44,Imagen45,Imagen46,Imagen47,Imagen48,Imagen49,Imagen50,Imagen51,Imagen52,Imagen53,Imagen54,Imagen55,Imagen56,Imagen57,Imagen58,Imagen59,Imagen60,Imagen61,Imagen62,Imagen63,Imagen64,Imagen65,Imagen66,Imagen67,Imagen68,Imagen69,Imagen70,Imagen71,Imagen72,Imagen73,Imagen74,Imagen75,Imagen76,Imagen77,Imagen78,Imagen79,Imagen80,Imagen81,Imagen82,Imagen83,Imagen84,Imagen85,Imagen86,Imagen87]

# %% [markdown]
# ### Filtrado y reducción de tamaño

# %%
Testf1 = AclararImg(Test[0])
Testf2 = AclararImg(Test[1])
Testf3 = AclararImg(Test[2])
Testf4 = AclararImg(Test[3])
Testf5 = AclararImg(Test[4])
Testf6 = AclararImg(Test[5])
Testf7 = AclararImg(Test[6])
Testf8 = AclararImg(Test[7])
Testf9 = AclararImg(Test[8])
Testf10 = AclararImg(Test[9])
Testf11 = AclararImg(Test[10])
Testf12 = AclararImg(Test[11])
Testf13 = AclararImg(Test[12])
Testf14 = AclararImg(Test[13])
Testf15 = AclararImg(Test[14])
Testf16 = AclararImg(Test[15])
Testf17 = AclararImg(Test[16])
Testf18 = AclararImg(Test[17])
Testf19 = AclararImg(Test[18])
Testf20 = AclararImg(Test[19])
Testf21 = AclararImg(Test[20])
Testf22 = AclararImg(Test[21])
Testf23 = AclararImg(Test[22])
Testf24 = AclararImg(Test[23])
Testf25 = AclararImg(Test[24])
Testf26 = AclararImg(Test[25])

Train1 = AclararImg(Train[0])
Train2 = AclararImg(Train[1])
Train3 = AclararImg(Train[2])
Train4 = AclararImg(Train[3])
Train5 = AclararImg(Train[4])
Train6 = AclararImg(Train[5])
Train7 = AclararImg(Train[6])
Train8 = AclararImg(Train[7])
Train9 = AclararImg(Train[8])
Train10 = AclararImg(Train[9])
Train11 = AclararImg(Train[10])
Train12 = AclararImg(Train[11])
Train13 = AclararImg(Train[12])
Train14 = AclararImg(Train[13])
Train15 = AclararImg(Train[14])
Train16 = AclararImg(Train[15])
Train17 = AclararImg(Train[16])
Train18 = AclararImg(Train[17])
Train19 = AclararImg(Train[18])
Train20 = AclararImg(Train[19])
Train21 = AclararImg(Train[20])
Train22 = AclararImg(Train[21])
Train23 = AclararImg(Train[22])
Train24 = AclararImg(Train[23])
Train25 = AclararImg(Train[24])
Train26 = AclararImg(Train[25])
Train27 = AclararImg(Train[26])
Train28 = AclararImg(Train[27])
Train29 = AclararImg(Train[28])
Train30 = AclararImg(Train[39])
Train31 = AclararImg(Train[30])
Train32 = AclararImg(Train[31])
Train33 = AclararImg(Train[32])
Train34 = AclararImg(Train[33])
Train35 = AclararImg(Train[34])
Train36 = AclararImg(Train[35])
Train37 = AclararImg(Train[36])
Train38 = AclararImg(Train[37])
Train39 = AclararImg(Train[38])
Train40 = AclararImg(Train[39])
Train41 = AclararImg(Train[40])
Train42 = AclararImg(Train[41])
Train43 = AclararImg(Train[42])
Train44 = AclararImg(Train[43])
Train45 = AclararImg(Train[44])
Train46 = AclararImg(Train[45])
Train47 = AclararImg(Train[46])
Train48 = AclararImg(Train[47])
Train49 = AclararImg(Train[48])
Train50 = AclararImg(Train[49])
Train51 = AclararImg(Train[50])
Train52 = AclararImg(Train[51])
Train53 = AclararImg(Train[52])
Train54 = AclararImg(Train[53])
Train55 = AclararImg(Train[54])
Train56 = AclararImg(Train[55])
Train57 = AclararImg(Train[56])
Train58 = AclararImg(Train[57])
Train59 = AclararImg(Train[58])
Train60 = AclararImg(Train[59])
Train61 = AclararImg(Train[60])

tamNo = (311,225)

TrainT = [cv2.resize(Train1,tamNo),cv2.resize(Train2,tamNo),cv2.resize(Train3,tamNo),cv2.resize(Train4,tamNo),cv2.resize(Train5,tamNo),cv2.resize(Train6,tamNo),cv2.resize(Train7,tamNo),cv2.resize(Train8,tamNo),cv2.resize(Train9,tamNo),cv2.resize(Train10,tamNo),cv2.resize(Train11,tamNo),cv2.resize(Train12,tamNo),cv2.resize(Train13,tamNo),cv2.resize(Train14,tamNo),cv2.resize(Train15,tamNo),cv2.resize(Train16,tamNo),cv2.resize(Train17,tamNo),cv2.resize(Train18,tamNo),cv2.resize(Train19,tamNo),cv2.resize(Train20,tamNo),cv2.resize(Train21,tamNo),cv2.resize(Train22,tamNo),cv2.resize(Train23,tamNo),cv2.resize(Train24,tamNo),cv2.resize(Train25,tamNo),cv2.resize(Train26,tamNo),cv2.resize(Train27,tamNo),cv2.resize(Train28,tamNo),cv2.resize(Train29,tamNo),cv2.resize(Train30,tamNo),cv2.resize(Train31,tamNo),cv2.resize(Train32,tamNo),cv2.resize(Train33,tamNo),cv2.resize(Train34,tamNo),cv2.resize(Train35,tamNo),cv2.resize(Train36,tamNo),cv2.resize(Train37,tamNo),cv2.resize(Train38,tamNo),cv2.resize(Train39,tamNo),cv2.resize(Train40,tamNo),cv2.resize(Train41,tamNo),cv2.resize(Train42,tamNo),cv2.resize(Train43,tamNo),cv2.resize(Train44,tamNo),cv2.resize(Train45,tamNo),cv2.resize(Train46,tamNo),cv2.resize(Train47,tamNo),cv2.resize(Train48,tamNo),cv2.resize(Train49,tamNo),cv2.resize(Train50,tamNo),cv2.resize(Train51,tamNo),cv2.resize(Train52,tamNo),cv2.resize(Train53,tamNo),cv2.resize(Train54,tamNo),cv2.resize(Train55,tamNo),cv2.resize(Train56,tamNo),cv2.resize(Train57,tamNo),cv2.resize(Train58,tamNo),cv2.resize(Train59,tamNo),cv2.resize(Train60,tamNo),cv2.resize(Train61,tamNo),cv2.resize(Testf1,tamNo), cv2.resize(Testf2,tamNo), cv2.resize(Testf3,tamNo), cv2.resize(Testf4,tamNo), cv2.resize(Testf5,tamNo), cv2.resize(Testf6,tamNo), cv2.resize(Testf7,tamNo), cv2.resize(Testf8,tamNo), cv2.resize(Testf9,tamNo), cv2.resize(Testf10,tamNo), cv2.resize(Testf11,tamNo), cv2.resize(Testf12,tamNo), cv2.resize(Testf13,tamNo), cv2.resize(Testf14,tamNo), cv2.resize(Testf15,tamNo), cv2.resize(Testf16,tamNo), cv2.resize(Testf17,tamNo), cv2.resize(Testf18,tamNo), cv2.resize(Testf19,tamNo), cv2.resize(Testf20,tamNo), cv2.resize(Testf21,tamNo), cv2.resize(Testf22,tamNo), cv2.resize(Testf23,tamNo), cv2.resize(Testf24,tamNo) , cv2.resize(Testf25,tamNo), cv2.resize(Testf26,tamNo)]

#TrainT = [Train1,Train2,Train3,Train4,Train5,Train6,Train7,Train8,Train9,Train10,Train11,Train12,Train13,Train14,Train15,Train16,Train17,Train18,Train19,Train20,Train21,Train22,Train23,Train24,Train25,Train26,Train27,Train28,Train29,Train30,Train31,Train32,Train33,Train34,Train35,Train36,Train37,Train38,Train39,Train40,Train41,Train42,Train43,Train44,Train45,Train46,Train47,Train48,Train49,Train50,Train51,Train52,Train53,Train54,Train55,Train56,Train57,Train58,Train59,Train60,Train61]
#TesT = [Testf1,Testf2,Testf3,Testf4,Testf5,Testf6,Testf7,Testf8,Testf9,Testf10,Testf11,Testf12,Testf13,Testf14,Testf14,Testf15,Testf16,Testf17,Testf18,Testf19,Testf20,Testf21,Testf22,Testf23,Testf24,Testf25,Testf26]

# %%
SetDatos = [Imagen1,Imagen2,Imagen3,Imagen4,Imagen5,Imagen6,Imagen7,Imagen8,Imagen9,Imagen10,Imagen11,Imagen12,Imagen13,Imagen14,Imagen15,Imagen16,Imagen17,Imagen18,Imagen19,Imagen20,Imagen21,Imagen22,Imagen23,Imagen24,Imagen25,Imagen26,Imagen27,Imagen28,Imagen29,Imagen30,Imagen31,Imagen32,Imagen33,Imagen34,Imagen35,Imagen36,Imagen37,Imagen38,Imagen39,Imagen40,Imagen41,Imagen42,Imagen43,Imagen44,Imagen45,Imagen46,Imagen47,Imagen48,Imagen49,Imagen50,Imagen51,Imagen52,Imagen53,Imagen54,Imagen55,Imagen56,Imagen57,Imagen58,Imagen59,Imagen60,Imagen61,Imagen62,Imagen63,Imagen64,Imagen65,Imagen66,Imagen67,Imagen68,Imagen69,Imagen70,Imagen71,Imagen72,Imagen73,Imagen74,Imagen75,Imagen76,Imagen77,Imagen78,Imagen79,Imagen80,Imagen81,Imagen82,Imagen83,Imagen84,Imagen85,Imagen86,Imagen87
]

# %%
#SetDatos = [AclararImg(Imagen1),AclararImg(Imagen2),AclararImg(Imagen3),AclararImg(Imagen4),AclararImg(Imagen5),AclararImg(Imagen6),AclararImg(Imagen7),AclararImg(Imagen8),AclararImg(Imagen9),AclararImg(Imagen10),AclararImg(Imagen11),AclararImg(Imagen12),AclararImg(Imagen13),AclararImg(Imagen14),AclararImg(Imagen15),AclararImg(Imagen16),AclararImg(Imagen17),AclararImg(Imagen18),AclararImg(Imagen19),AclararImg(Imagen20),AclararImg(Imagen21),AclararImg(Imagen22),AclararImg(Imagen23),AclararImg(Imagen24),AclararImg(Imagen25),AclararImg(Imagen26),AclararImg(Imagen27),AclararImg(Imagen28),AclararImg(Imagen29),AclararImg(Imagen30),AclararImg(Imagen31),AclararImg(Imagen32),AclararImg(Imagen33),AclararImg(Imagen34),AclararImg(Imagen35),AclararImg(Imagen36),AclararImg(Imagen37),AclararImg(Imagen38),AclararImg(Imagen39),AclararImg(Imagen40),AclararImg(Imagen41),AclararImg(Imagen42),AclararImg(Imagen43),AclararImg(Imagen44),AclararImg(Imagen45),AclararImg(Imagen46),AclararImg(Imagen47),AclararImg(Imagen48),AclararImg(Imagen49),AclararImg(Imagen50),AclararImg(Imagen51),AclararImg(Imagen52),AclararImg(Imagen53),AclararImg(Imagen549,AclararImg(Imagen55),AclararImg(Imagen56),AclararImg(Imagen57),AclararImg(Imagen58),AclararImg(Imagen59),AclararImg(Imagen60),AclararImg(Imagen61),AclararImg(Imagen62),AclararImg(Imagen63),AclararImg(Imagen64),AclararImg(Imagen65),AclararImg(Imagen66),AclararImg(Imagen67),AclararImg(Imagen68),AclararImg(Imagen69),AclararImg(Imagen70),AclararImg(Imagen71),AclararImg(Imagen72),AclararImg(Imagen73),AclararImg(Imagen74),AclararImg(Imagen75),AclararImg(Imagen76),AclararImg(Imagen77),AclararImg(Imagen78),AclararImg(Imagen79),AclararImg(Imagen80),AclararImg(Imagen81),AclararImg(Imagen82),AclararImg(Imagen83),AclararImg(Imagen84),AclararImg(Imagen85),AclararImg(Imagen86),AclararImg(Imagen87)]

# %% [markdown]
# ### Funciones utilizadas

# %%
# Funcion histograma
def histograma(ImG, MatrizRGB):
    MatrizRGB = ('b','g','r')
    for i,color in enumerate(MatrizRGB):
        hist = cv2.calcHist([imGGris],[i],None,[256],[0,256])
        plt.plot(hist,color = color)
    plt.title('Histograma')
    plt.show()
    
def gamma_filter(matrix, gamma):
    # Apply gamma correction to each pixel in the matrix
    gamma_corrected_matrix = np.power(matrix, gamma)
    return gamma_corrected_matrix


def lee_filter(img, size):
    img_mean = uniform_filter(img, (size, size))
    img_sqr_mean = uniform_filter(img**2, (size, size))
    img_variance = img_sqr_mean - img_mean**2

    overall_variance = variance(img)

    img_weights = img_variance**2 / (img_variance**2 + overall_variance**2)
    img_output = img_mean + img_weights * (img - img_mean)
    return img_output

def gamma_filter(matrix, gamma):
    # Apply gamma correction to each pixel in the matrix
    gamma_corrected_matrix = np.power(matrix, gamma)
    return gamma_corrected_matrix



def AclararImg(IM):
    kernel2 = np.ones((2,2))
    return  cv2.filter2D(IM,-1,kernel2)

# Funcion histograma
def histograma(ImG, MatrizRGB):
    MatrizRGB = ('b','g','r')
    for i,color in enumerate(MatrizRGB):
        hist = cv2.calcHist([ImG],[i],None,[256],[0,256])
        plt.plot(hist,color = color)
    plt.title('Histograma')
    plt.show()


def sif_t(I):
    #gray = cv2.cvtColor(I,cv2.COLOR_BGR2GRAY)
    sift = cv2.SIFT_create()
    kp = sift.detect(I,None)
    kp2,des = sift.compute(I,kp)
    
    return cv2.drawKeypoints(I,kp,I,flags=cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)

# %% [markdown]
# ### Datos

# %%
Test=[Imagen1,Imagen2,Imagen3,Imagen4,Imagen5,Imagen6,Imagen7,Imagen8,Imagen9,Imagen10,Imagen11,Imagen12,Imagen13,Imagen14,Imagen15,Imagen16,Imagen17,Imagen18,Imagen19,Imagen20,Imagen21,Imagen22,Imagen23,Imagen24,Imagen25,Imagen26]
Train=[Imagen27,Imagen28,Imagen29,Imagen30,Imagen31,Imagen32,Imagen33,Imagen34,Imagen35,Imagen36,Imagen37,Imagen38,Imagen39,Imagen40,Imagen41,Imagen42,Imagen43,Imagen44,Imagen45,Imagen46,Imagen47,Imagen48,Imagen49,Imagen50,Imagen51,Imagen52,Imagen53,Imagen54,Imagen55,Imagen56,Imagen57,Imagen58,Imagen59,Imagen60,Imagen61,Imagen62,Imagen63,Imagen64,Imagen65,Imagen66,Imagen67,Imagen68,Imagen69,Imagen70,Imagen71,Imagen72,Imagen73,Imagen74,Imagen75,Imagen76,Imagen77,Imagen78,Imagen79,Imagen80,Imagen81,Imagen82,Imagen83,Imagen84,Imagen85,Imagen86,Imagen87]

# %%
#cv2.imshow('TmaNoReal',Testf4)
#cv2.imshow('Reducida',TesT[3])
#print(Train58.shape)
#print(TrainT[57].shape)
#plt.show()
#cv2.waitKey(0)
#cv2.destroyAllWindows()

# %%
#colors = ('b','g','r')
#histograma(Train61,colors)

#histograma(Imagen87,colors)

#cv2.waitKey(0)
#cv2.destroyAllWindows()

# %% [markdown]
# ### Normalización

# %%
def Normalizar(Img):
    Img = tf.cast(Img,tf.float32)
    Img /= 255 # Paso de 0-255 a 0-1
    return Img

# %%
DatNorTrain = Normalizar(TrainT)
DatNorTest = Normalizar(TesT)

# %%
plt.figure()
plt.show(DatNorTrain)
#cv2.imshow('imGGris1',DatNorTrain[1])
#plt.show()
#cv2.waitKey(0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 2
#       1 plt.figure()
# ----> 2 plt.show(DatNorTrain)
#
# File ~\anaconda3\Lib\site-packages\matplotlib\pyplot.py:446, in show(*args, **kwargs)
#     402 """
#     403 Display all open figures.
#     404
#    (...)
#     443 explicitly there.
#     444 """
#     445 _warn_if_gui_out_of_main_thread()
# --> 446 return _get_backend_mod().show(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\matplotlib_inline\backend_inline.py:98, in show(close, block)
#      95 show._to_draw = []
#      96 # only call close('all') if any to close
#      97 # close triggers gc.collect, which can be slow
# ---> 98 if close and Gcf.get_all_fig_managers():
#      99     matplotlib.pyplot.close('all')
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\framework\ops.py:300, in _EagerTensorBase.__bool__(self)
# ...

# %% [markdown]
# ### Umbralización

# %%
_, imgCl2 = cv2.threshold(TesT[0],55,255, cv2.THRESH_BINARY)

cv2.imshow('imGGris1',imgCl2)
plt.show()
cv2.waitKey(0)
#cv2.destroyAllWindows()

# %%
_, imgCl1 = cv2.threshold(imgCll1,55,255, cv2.THRESH_BINARY)
_, imgCl2 = cv2.threshold(imgCll2,55,255, cv2.THRESH_BINARY)
cv2.imshow('imGGris',imgCll1)
cv2.imshow('imGGris1',imgCll2)
plt.show()
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
Matriz_np1 = np.asarray(imgCll1)

# %%
np.save("np1_Save.npy",Matriz_np1)

# %% [markdown]
# ## Método 1 para calcular los descriptores

# %%
IMgft1 = sif_t(imgCll1)
IMgft2 = sif_t(imgCll2)

bf = cv2.BFMatcher(cv2.NORM_L1, crossCheck=True)

matches = bf.match(descriptors_1,descriptors_2)
matches = sorted(matches, key = lambda x:x.distance)

img3 = cv2.drawMatches(imgCl1, keypoints_1, imgCl2, keypoints_2, matches[:50], imgCl2, flags=2)

figure, ax = plt.subplots(1, 1, figsize=(16, 8))
ax.imshow(img3, cmap='gray')

#print(descriptors_1,descriptors_2)

cv2.imshow('sif_t1',IMgft1)
cv2.imshow('sif_t2',IMgft2)
cv2.waitKey(0)
# Out:
# -1

# %% [markdown]
# ## Método 2 para calcular los descriptores

# %%
sift = cv2.SIFT_create()
keypoints_1, descriptors_1=sift.detectAndCompute(imgCll1,None) 
keypoints_2, descriptors_2=sift.detectAndCompute(imgCll2,None) 

bf = cv2.BFMatcher(cv2.NORM_L1, crossCheck=True)

matches = bf.match(descriptors_1,descriptors_2)
matches = sorted(matches, key = lambda x:x.distance)

img3 = cv2.drawMatches(imgCl1, keypoints_1, imgCl2, keypoints_2, matches[:50], imgCl2, flags=2)

figure, ax = plt.subplots(1, 1, figsize=(16, 8))
ax.imshow(img3, cmap='gray')

#cv2.imshow('sif_t1',IMgft1)
#cv2.imshow('sif_t2',IMgft2)
#cv2.waitKey(0)
#cv2.destroyAllWindows()

#print(descriptors_1,descriptors_2)

#plt.show()
#cv2.imshow('sift',img3)

#cv2.waitKey(0)
#cv2.destroyAllWindows()

# %%
descriptors_2=descriptors_2/255
print(descriptors_2[20].shape)
print(descriptors_2[20])
# Out:
# (128,)
# [0.49411765 0.1882353  0.07058824 0.00784314 0.         0.
#  0.         0.02745098 0.5529412  0.33333334 0.02352941 0.00392157
#  0.         0.         0.         0.03137255 0.10588235 0.14117648
#  0.22352941 0.14117648 0.04705882 0.04313726 0.00392157 0.01176471
#  0.23137255 0.12156863 0.05882353 0.04313726 0.03137255 0.03137255
#  0.01960784 0.13333334 0.40784314 0.11764706 0.01568628 0.02352941
#  0.00392157 0.         0.         0.17254902 0.5529412  0.43137255
#  0.01960784 0.01176471 0.00392157 0.00392157 0.01568628 0.07058824
#  0.21568628 0.06666667 0.05882353 0.07843138 0.03137255 0.09411765
#  0.28235295 0.19607843 0.22745098 0.10588235 0.02745098 0.01568628
#  0.02745098 0.02352941 0.1254902  0.22745098 0.19607843 0.02745098
#  0.01960784 0.15294118 0.03137255 0.         0.00392157 0.28627452
#  0.5529412  0.08235294 0.00784314 0.01568628 0.00392157 0.
#  0.00392157 0.43137255 0.5294118  0.10588235 0.10588235 0.03137255
# ...

# %%
#sift = cv2.SIFT_create()
#keypoints_1 = sift.detect(imgCl1,None)#Puntos clave
#keypoints_1,descriptors_1 = sift.compute(imgCl1,keypoints_1)#Descriprotes
#RV= cv2.drawKeypoints(imgCl1,keypoints_1,imgCl1,flags=cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)


#keypoints_2 = sift.detect(imgCl2,None)#Puntos clave
#keypoints_2,descriptors_2 = sift.compute(imgCl2,keypoints_2)#Descriprotes
#RV2= cv2.drawKeypoints(imgCl2,keypoints_2,imgCl2,flags=cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)

# %%
#def sif_t2(I):
#    sift = cv2.SIFT_create()
#    #gray = cv2.cvtColor(I,cv2.COLOR_BGR2GRAY)
#    keypoints_1 = sift.detect(imgCl1,None)#Puntos clave
#    keypoints_1,descriptors_1 = sift.compute(imgCl1,keypoints_1)#Descriprotes
#    RV= cv2.drawKeypoints(imgCl1,keypoints_1,imgCl1,flags=cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)
#    return[keypoints_1,keypoints_2,descriptors_1,descriptors_2,RV]
